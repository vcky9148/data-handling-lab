# %%
# Program to plot 2-D Heat map
# using matplotlib.pyplot.imshow() method
import numpy as np
import matplotlib.pyplot as plt
data = np.random.random(( 13 , 16 ))
plt.imshow( data,cmap="magma" )
plt.title( "2-D Heat Map" )
plt.colorbar()
plt.show()

# %%
# Program to plot 2-D Heat map
# using matplotlib.pyplot.imshow() method
import numpy as np
import matplotlib.pyplot as plt

data = np.random.random((12, 12))
plt.imshow(data, cmap='autumn')

plt.title("Heatmap with different color")
plt.show()

# %%
# importing the modules
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# generating 2-D 10x10 matrix of random numbers
# from 1 to 100
data = np.random.randint(low=14,
						high=100,
						size=(10, 10))
# plotting the heatmap
hm = sns.heatmap(data=data,annot=True)
# displaying the plotted heatmap
plt.show()

# %%
# Density Plot with Seaborn defaults:
x, y = np.random.multivariate_normal([0, 0], [[1, -.5], [-.5, 1]], size=300).T

sample_cmap = sns.cubehelix_palette(light=1, as_cmap=True)
sns.kdeplot((x, y), cmap=sample_cmap, shade=True)
# Out:
# <ipython-input-9-dc72064cfa87>:5: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot((x, y), cmap=sample_cmap, shade=True)
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-9-dc72064cfa87> in <cell line: 5>()
#       3
#       4 sample_cmap = sns.cubehelix_palette(light=1, as_cmap=True)
# ----> 5 sns.kdeplot((x, y), cmap=sample_cmap, shade=True)
#
# /usr/local/lib/python3.10/dist-packages/seaborn/distributions.py in kdeplot(data, x, y, hue, weights, palette, hue_order, hue_norm, color, fill, multiple, common_norm, common_grid, cumulative, bw_method, bw_adjust, warn_singular, log_scale, levels, thresh, gridsize, cut, clip, legend, cbar, cbar_ax, cbar_kws, ax, **kwargs)
#    1699         plot_kws = kwargs.copy()
#    1700
# -> 1701         p.plot_univariate_density(
#    1702             multiple=multiple,
#    1703             common_norm=common_norm,
#
# /usr/local/lib/python3.10/dist-packages/seaborn/distributions.py in plot_univariate_density(self, multiple, common_norm, common_grid, warn_singular, fill, color, legend, estimate_kws, **plot_kws)
#    1022
#    1023             ax_obj = self.ax if self.ax is not None else self.facets
# -> 1024             self._add_legend(
#    1025                 ax_obj, artist, fill, False, multiple, alpha, plot_kws, {},
#    1026             )
#
# /usr/local/lib/python3.10/dist-packages/seaborn/distributions.py in _add_legend(self, ax_obj, artist, fill, element, multiple, alpha, artist_kws, legend_kws)
#     154                 kws.pop("color", None)
#     155
# --> 156             handles.append(artist(**kws))
#     157             labels.append(level)
#     158
#
# /usr/local/lib/python3.10/dist-packages/matplotlib/_api/deprecation.py in wrapper(*args, **kwargs)
#     452                 "parameter will become keyword-only %(removal)s.",
#     453                 name=name, obj_type=f"parameter of {func.__name__}()")
# --> 454         return func(*args, **kwargs)
#     455
#     456     # Don't modify *func*'s signature, as boilerplate.py needs it.
#
# /usr/local/lib/python3.10/dist-packages/matplotlib/patches.py in __init__(self, edgecolor, facecolor, color, linewidth, linestyle, antialiased, hatch, fill, capstyle, joinstyle, **kwargs)
#      98
#      99         if len(kwargs):
# --> 100             self._internal_update(kwargs)
#     101
#     102     def get_verts(self):
#
# /usr/local/lib/python3.10/dist-packages/matplotlib/artist.py in _internal_update(self, kwargs)
#    1221         The lack of prenormalization is to maintain backcompatibility.
#    1222         """
# -> 1223         return self._update_props(
#    1224             kwargs, "{cls.__name__}.set() got an unexpected keyword argument "
#    1225             "{prop_name!r}")
#
# /usr/local/lib/python3.10/dist-packages/matplotlib/artist.py in _update_props(self, props, errfmt)
#    1195                     func = getattr(self, f"set_{k}", None)
#    1196                     if not callable(func):
# -> 1197                         raise AttributeError(
#    1198                             errfmt.format(cls=type(self), prop_name=k))
#    1199                     ret.append(func(v))
#
# AttributeError: Patch.set() got an unexpected keyword argument 'cmap'

# %%
sns.palplot(sns.cubehelix_palette(n_colors=8, start=1.7, rot=0.2, dark=0, light=.95, reverse=True))

# %%
# Loading up built-in dataset:
tips = sns.load_dataset("tips")

# Creating Strip plot for day-wise revenue:
sns.stripplot(x="day", y="total_bill", data=tips, color="g")
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %%
# Set Theme:
sns.set_style('whitegrid')

# Creating Strip plot for day-wise revenue:
sns.swarmplot(x="day", y="total_bill", data=tips, palette="viridis")
# Out:
# <ipython-input-6-fee5fbe70d4b>:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.swarmplot(x="day", y="total_bill", data=tips, palette="viridis")
# <Axes: xlabel='day', ylabel='total_bill'>

# %%
iris = sns.load_dataset("iris")

sns.boxplot(x="species", y="petal_length", data=iris, palette="cividis")
# Out:
# <ipython-input-7-4f1143658a8b>:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x="species", y="petal_length", data=iris, palette="cividis")
# <Axes: xlabel='species', ylabel='petal_length'>
